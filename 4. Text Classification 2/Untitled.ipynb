# %%
import numpy as np
import pandas as pd

dataset  = pd.read_csv('message.csv')

# %%
dataset.isnull().sum()
# Out:
# SMS_id    0
# SMS       0
# dtype: int64

# %%
dataset
# Out:
#       SMS_id                                                SMS
# 0          1   \tGo until jurong point, crazy.. Available on...
# 1          2                  \tOk lar... Joking wif u oni...\n
# 2          3   \tFree entry in 2 a wkly comp to win FA Cup f...
# 3          4   \tU dun say so early hor... U c already then ...
# 4          5   \tNah I don't think he goes to usf, he lives ...
# 5          6   \tFreeMsg Hey there darling it's been 3 week'...
# 6          7   \tEven my brother is not like to speak with m...
# 7          8   \tAs per your request 'Melle Melle (Oru Minna...
# 8          9   \tWINNER!! As a valued network customer you h...
# 9         10   \tHad your mobile 11 months or more? U R enti...
# 10        11   \tI'm gonna be home soon and i don't want to ...
# 11        12   \tSIX chances to win CASH! From 100 to 20,000...
# 12        13   \tURGENT! You have won a 1 week FREE membersh...
# 13        14   \tI've been searching for the right words to ...
# ...
